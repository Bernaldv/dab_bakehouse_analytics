# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %% [markdown]
# #Customer 360
# Clientes por país. Lo ejecuta el job `bakehouse_data_refresh`.

# %%
# Para probar a mano: descomentar, ejecutar y volver a comentar antes del commit.
# dbutils.widgets.removeAll()
# dbutils.widgets.text("catalog", "bakehouse_analytics_dev")
# dbutils.widgets.text("schema", "rnd"

# %%
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}")
spark.sql(f"USE SCHEMA {schema}")

# %%
spark.sql(f"""
CREATE OR REPLACE TABLE {catalog}.{schema}.customer_360 AS
SELECT country,
COUNT(*) AS number_of_customers,
COUNT_IF(gender = 'female') AS female_customers,
COUNT_IF(gender = 'male') AS male_customers
FROM samples.bakehouse.sales_customers
GROUP BY country
""")
